# %% [markdown]
# <a href="https://colab.research.google.com/github/DaanishSharma/HelloWorld/blob/master/CovidMaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import csv
import folium
import datetime
from folium import plugins
from folium.plugins import HeatMap, MarkerCluster
# !wget --no-check-certificate \
   https://covid.ourworldindata.org/data/owid-covid-data.csv \
    -O /data.csv
# !wget --no-check-certificate \
   https://docs.google.com/spreadsheets/d/e/2PACX-1vSSd4CA6Bq88H4_GdKuG8f5u7yrASn58gklL61yCexF3XEmMTxgKbs-0PbKzTNINef55Rq4Yem5CE7l/pub?output=csv \
    -O /geo_data.csv  
d=pd.read_csv("/data.csv")
g=d.groupby("date")
c=d.groupby("location")
dates=[ date for date , date_df in g]
ctries=[str(i) for i , df in c]
dte=dates[-1]    
cases=g.get_group(dte)  
l=pd.read_csv("/geo_data.csv", error_bad_lines=False)
l2=set(l.name)
l1=set(ctries)
data0=[[float(l.loc[l.name==i]["latitude"]),float(l.loc[l.name==i]["longitude"]),(cases.loc[cases.location==i]["new_cases"])] for i in l1.intersection(l2)]
for j in data0:
  if len(list(j[2]))==0:
    j[2]=0
  else:
    j[2]=int(j[2])

# %% [markdown]
# **NEW CASES**

# %%
# map
map_enum_icons = folium.Map([38, -98], zoom_start=4)

for i in data0:
    folium.Marker(location=[i[0], i[1]],
                  icon=plugins.BeautifyIcon(
                  number=int(i[2]),
                  border_color='blue',
                  border_width=1,
                  text_color='black',
                  )).add_to(map_enum_icons)

# display map    
map_enum_icons
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map=folium.Map(location=[32,120], zoom_start=5)
HeatMap(data0,radius=20).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **TOTAL** **CASES**

# %%
data0=[[float(l.loc[l.name==i]["latitude"]),float(l.loc[l.name==i]["longitude"]),(cases.loc[cases.location==i]["total_cases"])] for i in l1.intersection(l2)]
for j in data0:
  if len(list(j[2]))==0:
    j[2]=0
  else:
    j[2]=int(j[2])  
# map
map_enum_icons = folium.Map([10, 50], zoom_start=4)

for i in data0:
    folium.Marker(location=[i[0], i[1]],
                  icon=plugins.BeautifyIcon(
                  number=int(i[2]),
                  border_color='blue',
                  border_width=1,
                  text_color='black',
                  )).add_to(map_enum_icons)

# display map    
map_enum_icons
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map center[32,120], zoom levels = 5
map=folium.Map(location=[40,0], zoom_start=5)
# add heat map to the map we just created

HeatMap(data0,radius=20).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
